# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SP\\Desktop\\Datascience_with_Python\\Python'

# %%
movies = pd.read_csv(r'P4-Movie-Ratings.csv')

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre', 'CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
#change dtypes for categorical values

movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Year.cat.categories
# Out:
# Int64Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
movies.Film.cat.categories
# Out:
# Index(['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours',
#        '17 Again ', '2012', '27 Dresses', '30 Days of Night',
#        '30 Minutes or Less', '50/50',
#        ...
#        'Yes Man', 'Yogi Bear', 'You Again', 'You Don't Mess with the Zohan',
#        'You Will Meet a Tall Dark Stranger', 'Your Highness',
#        'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper'],
#       dtype='object', length=559)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Jointplot

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
h = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind='hex')

# %%
h1 = sns.jointplot(data=movies, x='CriticRating', y='BudgetMillions',kind='hex')

# %%
k = sns.jointplot(data=movies, x='AudienceRating', y='BudgetMillions',kind='kde')

# %%
r = sns.jointplot(data=movies, x='AudienceRating', y='Year',kind='resid')

# %%
R = sns.jointplot(data=movies, x='AudienceRating', y='CriticRating',kind='reg')

# %% [markdown]
# ---

# %%
#histograms

# %%
m1 = sns.distplot(movies.AudienceRating, bins=15)

# %%
m2 = sns.distplot(movies.CriticRating, bins=15)

# %%
n1 = plt.hist(movies.AudienceRating, bins =15)

# %%
sns.set_style("darkgrid")

# %%
n1 = plt.hist(movies.BudgetMillions, bins =15)

# %% [markdown]
# ---

# %%
#Stacked Histograms

# %%
h3 = plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins =15)
h1 = plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions,bins =15)
h2 = plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions,bins =15)

plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,
                movies[movies.Genre == 'Drama'].BudgetMillions],bins=15,stacked=True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = []
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
list1
# Out:
# [2       20
#  5      200
#  15      35
#  29      20
#  30      20
#  33     237
#  36      45
#  39      45
#  40      70
#  45     150
#  49      68
#  52      17
#  58     140
#  60      85
#  63      40
#  66     125
#  67      25
#  69      40
#  70      90
#  73      30
#  76     163
#  77      13
#  81      25
#  83      20
#  86      45
#  94      30
#  98      33
#  101     75
#  102     30
#  106     45
#        ...
#  433    138
#  435     50
#  439     40
#  441     80
#  443    150
#  448     25
#  451     40
#  454    145
#  458    100
#  472    150
#  473      6
#  474      0
#  477    100
#  479     75
#  493    150
#  495     35
#  499    150
#  500    195
#  501    210
#  502     30
#  504    170
#  512     35
#  514     95
#  528     75
#  530     25
#  531    130
#  542     35
#  546    150
#  547    160
#  557     24
#  Name: BudgetMillions, Length: 154, dtype: int64, 1      105
#  3       18
#  19     200
#  21      45
#  24      40
#  32      78
#  46      20
# ...

# %%
list1 = []
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)

plt.hist(list1,bins=15,stacked=True, rwidth=1)
plt.show()

# %% [markdown]
# ---

# %%
#KDE - Kernel Density Estimation plot

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',
                  fit_reg=False, hue='Genre', size = 7, aspect=1)

# %%
vis2 = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind='kde')

# %%
vis3 = sns.kdeplot(movies.CriticRating, movies.AudienceRating)

# %%
vis4 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True)

# %%
vis5 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True,
                  shade_lowest = False, cmap='Reds')

# %%
vis5 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap='Reds')

# %% [markdown]
# ---

# %%
#Working with Subplots

# %%
sns.set_style("dark")
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
f, ax = plt.subplots(1,2)

# %%
f, ax = plt.subplots(3,2, figsize=(12,6))

# %%
f, axes = plt.subplots(1,2, figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating,ax=axes[1])

# %%
f, axes = plt.subplots(2,2, figsize=(12,6))
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating,ax=axes[0,1])
k3 = sns.kdeplot(movies.CriticRating, movies.AudienceRating,ax=axes[1,0])

# %%
f, axes = plt.subplots(1,2, figsize=(12,6),sharex = True,sharey=True)
k1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating,ax=axes[1])
#k1.set(xlim=(0,100))

# %% [markdown]
# ---

# %%
#Violinplots and boxplots

# %%
z = sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %%
w = sns.boxplot(data=movies, x='Genre', y='CriticRating')

# %%
z1 = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
w1 = sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %% [markdown]
# ---

# %%
#FacetGrids

# %%
g = sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')

# %%
g = sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
#can populate with any type of maps

# %%
g = sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')
g = g.map(plt.hist,'BudgetMillions')

# %%
g = sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')
kws = dict(s=50,linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws)

# %% [markdown]
# ---

# %%
#Controlling co-ordinates and diagonal on FacetGrid

g = sns.FacetGrid(movies, row='Genre',col='Year',hue='Genre')
kws = dict(s=50,linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws)

g.set(xlim=(0,100),ylim=(0,100))

for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c="gray", ls="--")
g.add_legend()

# %% [markdown]
# ---
